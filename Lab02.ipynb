# %% [markdown]
# <a href="https://colab.research.google.com/github/awaisaltaf5/Python-Practice-Code/blob/main/Lab02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This is comment
print("Muhammad Awais Altaf")
# Out:
# Hello

# %%
a=10
b=20
sum=a+b
print(sum)
# Out:
# 30

# %%
i = 1
while i <= 5:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num_int = 10
num_float = 3.14
num_double = 2.718281828
is_active = True
print("Integer:", type(num_int))
print("Float:", num_float)
print("Double (float in Python):", num_double)
print("Boolean:", is_active)
# Out:
# Integer: <class 'int'>
# Float: 3.14
# Double (float in Python): 2.718281828
# Boolean: True

# %%
print("1.Soup and salad")
print("2.Pasta with meat sauce")
print("3.Chef's Special")
choice=input("Which number would you like to order?")
if choice=="1":
  print("Soup and salad is orderd")
elif choice=="2":
  print("Pasta with meat sauce is orderd")
elif choice=="3":
  print("Chef's Special is orderd")
else:
  print("Invalid choice")
# Out:
# 1.Soup and salad
# 2.Pasta with meat sauce
# 3.Chef's Special
# Which number would you like to order?4
# Invalid choice

# %%
john = 3
mary = 5
adam = 6
print(john, ",", mary, ",", adam)
totalApples = john + mary + adam
print("Total apples:", totalApples)
if totalApples > 10:
    print("The total number of apples is greater than 10.")
elif totalApples < 10:
    print("The total number of apples is smaller than 10.")
else:
    print("The total number of apples is exactly 10.")
# Out:
# 3 , 5 , 6
# Total apples: 14
# The total number of apples is greater than 10.

# %%
a = 19
b = 3
# Addition
print("Addition:", a + b)
# Subtraction
print("Subtraction:", a - b)
# Multiplication
print("Multiplication:", a * b)
# Classic Division (returns float)
print("Division:", a / b)
# Modulus (remainder)
print("Modulus:", a % b)
# Exponent (power)
print("Exponent:", 2 ** 4)
# Floor Division (integer division)
print("Floor Division:", a // b)
# Out:
# Addition: 22
# Subtraction: 16
# Multiplication: 57
# Division: 6.333333333333333
# Modulus: 1
# Exponent: 16
# Floor Division: 6
