# %% [markdown]
# <a href="https://colab.research.google.com/github/awaisaltaf5/Python-Practice-Code/blob/main/Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
def sum_two_numbers(a, b):
  return a + b

num1 = 5
num2 = 7
result = sum_two_numbers(num1, num2)
print(f"The sum of {num1} and {num2} is: {result}")
# Out:
# The sum of 5 and 7 is: 12

# %%
number = int(input("Enter a number: "))


if number % 2 == 0:
    print(f"{number} is Even.")
else:
    print(f"{number} is Odd.")
# Out:
# Enter a number: 4
# 4 is Even.
